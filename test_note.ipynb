# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/loain/OneDrive/Desktop/data_vis_proj/Stores.csv')

# %%
df = pd.read_csv('C:/Users/loain/OneDrive/Desktop/ds_salaries.csv')
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
print('This columns is catocrical columns , so we can not provied overview for them : \n',set(df.columns) - set(df._get_numeric_data().columns))
# Out:
# This columns is catocrical columns , so we can not provied overview for them :
#  {'employee_residence', 'company_size', 'company_location', 'job_title', 'salary_currency', 'experience_level', 'employment_type'}

# %%
df._get_numeric_data()
# Out:
#      Unnamed: 0  work_year  salary  salary_in_usd  remote_ratio
# 0             0       2020   70000          79833             0
# 1             1       2020  260000         260000             0
# 2             2       2020   85000         109024            50
# 3             3       2020   20000          20000             0
# 4             4       2020  150000         150000            50
# ..          ...        ...     ...            ...           ...
# 602         602       2022  154000         154000           100
# 603         603       2022  126000         126000           100
# 604         604       2022  129000         129000             0
# 605         605       2022  150000         150000           100
# 606         606       2022  200000         200000           100
#
# [607 rows x 5 columns]

# %%
def overviwe (df):
    df = df._get_numeric_data()
    count_uin = []

    for i in range(0,len(df.columns)):
        count_uin.append(len(df.iloc[:,i].unique()))
    
    count_0 = (df == 0).sum()
    
    count_neg=(df < 0).sum()
    
    count_inf = np.isinf(df).sum()
    
    dff = pd.DataFrame(data = [count_uin,list(dict(count_0).values()),
    list(dict(count_neg).values()),list(dict(count_inf).values())
                              ]
    ,index=['Distinc','zeros','Negitives','Infinty'
           ],
    columns=df.columns
    )
    return dff

# %%
df_over = overviwe(df)

# %%
df_over
# Out:
#            Unnamed: 0  work_year  salary  salary_in_usd  remote_ratio
# Distinc           607          3     272            369             3
# zeros               1          0       0              0           127
# Negitives           0          0       0              0             0
# Infinty             0          0       0              0             0

# %%
df_des = df.describe()

# %%
df_des
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
df_merg =  df_des.append(df_over)

# %%
print(str(df_merg['work_year']))
# Out:
# count         607.000000
# mean         2021.405272
# std             0.692133
# min          2020.000000
# 25%          2021.000000
# 50%          2022.000000
# 75%          2022.000000
# max          2022.000000
# Distinc         3.000000
# zeros           0.000000
# Negitives       0.000000
# Infinty         0.000000
# Name: work_year, dtype: float64

# %%
str(df_merg['work_year'])
import re


re.sub(r'(      )'," | ",str(re.sub(r'(\n)'," \n ",str(df_merg['work_year']))))
# Out:
# 'count |    607.000000 \n mean |    2021.405272 \n std |  |  0.692133 \n min |     2020.000000 \n 25% |     2021.000000 \n 50% |     2022.000000 \n 75% |     2022.000000 \n max |     2022.000000 \n Distinc |    3.000000 \n zeros |      0.000000 \n Negitives |  0.000000 \n Infinty |    0.000000 \n Name: work_year, dtype: float64'

# %%
print(df_merg['work_year'].index[1])
# Out:
# mean

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 602    False
# 603    False
# 604    False
# 605    False
# 606    False
# Length: 607, dtype: bool

# %%
df.isnull().values.any()
str(df.isnull().sum())
# Out:
# 'Unnamed: 0            0\nwork_year             0\nexperience_level      0\nemployment_type       0\njob_title             0\nsalary                0\nsalary_currency       0\nsalary_in_usd         0\nemployee_residence    0\nremote_ratio          0\ncompany_location      0\ncompany_size          0\ndtype: int64'

# %%
j=0
for i in df_merg['work_year']:
    print(df_merg['work_year'].index[j]+'\t'+str(i))
    j+=1
# Out:
# count	607.0
# mean	2021.4052718286655
# std	0.692132985452652
# min	2020.0
# 25%	2021.0
# 50%	2022.0
# 75%	2022.0
# max	2022.0
# Distinc	3.0
# zeros	0.0
# Negitives	0.0
# Infinty	0.0

# %%
import plotly.express as px

# %%
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
fig = px.scatter(list(df['work_year']),list(df['salary_in_usd']))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15312\247103907.py in <cell line: 2>()
#       1 fig = px.scatter(list(df['work_year']),list(df['salary_in_usd']))
# ----> 2 fig.show()
#
# c:\Users\loain\AppData\Local\Programs\Python\Python39\lib\site-packages\plotly\basedatatypes.py in show(self, *args, **kwargs)
#    3395         import plotly.io as pio
#    3396
# -> 3397         return pio.show(self, *args, **kwargs)
#    3398
#    3399     def to_json(self, *args, **kwargs):
#
# c:\Users\loain\AppData\Local\Programs\Python\Python39\lib\site-packages\_plotly_utils\importers.py in __getattr__(import_name)
#      34             rel_module = ".".join(rel_path_parts[:-1])
#      35             class_name = import_name
# ---> 36             class_module = importlib.import_module(rel_module, parent_name)
# ...
